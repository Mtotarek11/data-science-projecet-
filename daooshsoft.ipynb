# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# Data Wrangling

# %%
print("Dimensions of DF: ", df.shape)
# Out:
# Dimensions of DF:  (607, 12)

# %%
print("\nInformation about DF: ")# print Information of DF
df.info()
# Out:
# Information about DF:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
print("Head of DF: ") # First fifth rows of DF
df.head(5)
# Out:
# Head of DF:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# What is the average salary?

# %%
df['salary_currency'].max()
# Out:
# 'USD'

# %% [markdown]
# what is the least used currency?

# %%
df['salary_currency'].min()
# Out:
# 'AUD'

# %% [markdown]
# what is the least salary in USD?

# %%
df[df['salary'] == df['salary'].max()]
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 177         177       2021               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 177  30400000             CLP          40038                 CL           100
#
#     company_location company_size
# 177               CL            L

# %% [markdown]
# what is the year and job with the lowest salary?

# %%
df[df['salary'] == df['salary'].min()]
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 185         185       2021               MI              FT   Data Engineer
# 238         238       2021               EN              FT  Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 185    4000             USD           4000                 IR           100
# 238    4000             USD           4000                 VN             0
#
#     company_location company_size
# 185               IR            M
# 238               VN            M

# %% [markdown]
# what was the max of all employees work_year?(2020-2023)?

# %%
df.groupby('work_year').max()
# Out:
#            Unnamed: 0 experience_level employment_type             job_title  \
# work_year
# 2020               71               SE              PT    Research Scientist
# 2021              288               SE              PT  Staff Data Scientist
# 2022              606               SE              PT    Research Scientist
#
#              salary salary_currency  salary_in_usd employee_residence  \
# work_year
# 2020       11000000             USD         450000                 US
# 2021       30400000             USD         600000                 VN
# 2022        6000000             USD         405000                 US
#
#            remote_ratio company_location company_size
# work_year
# 2020                100               US            S
# 2021                100               VN            S
# 2022                100               US            S

# %% [markdown]
# what was the max of all employees salary_in_usd ?(2020-2023)?

# %%
df.groupby('salary_in_usd').max()
# Out:
#                Unnamed: 0  work_year experience_level employment_type  \
# salary_in_usd
# 2859                  176       2021               MI              FT
# 4000                  238       2021               MI              FT
# 5409                   77       2021               MI              PT
# 5679                  179       2021               MI              FT
# 5707                   18       2020               EN              FT
# ...                   ...        ...              ...             ...
# 412000                 63       2020               SE              FT
# 416000                225       2021               EX              CT
# 423000                157       2021               MI              FT
# 450000                 97       2021               MI              FT
# 600000                252       2021               EX              FT
#
#                                         job_title  salary salary_currency  \
# salary_in_usd
# ...
